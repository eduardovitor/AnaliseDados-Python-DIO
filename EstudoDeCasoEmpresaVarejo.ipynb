# %%
# !pip install pandas

# %%
import pandas as pd

# %%
dataset_clientes = pd.read_excel("Dados.xlsx", sheet_name="Clientes")
dataset_vendedores = pd.read_excel("Dados.xlsx", sheet_name="Vendedores")
dataset_produtos = pd.read_excel("Dados.xlsx", sheet_name="Produtos")
dataset_vendas = pd.read_excel("Dados.xlsx", sheet_name="Vendas")
dataset_itensvendas = pd.read_excel("Dados.xlsx", sheet_name="ItensVendas")

# %% [markdown]
# ### Visualizando dados dos clientes

# %%
dataset_clientes.head(10)
# Out:
#    ClienteID               Cliente Estado Sexo    Status
# 0          1  Adelina Buenaventura     RJ    M    Silver
# 1          2          Adelino Gago     RJ    M    Silver
# 2          3       Adolfo Patrício     PE    M    Silver
# 3          4      Adriana Guedelha     RO    F  Platinum
# 4          5         Adélio Lisboa     SE    M    Silver
# 5          6         Adérito Bahía     MA    M    Silver
# 6          7         Aida Dorneles     RN    F    Silver
# 7          8     Alarico Quinterno     AC    M    Silver
# 8          9      Alberto Cezimbra     AM    M    Silver
# 9         10      Alberto Monsanto     RN    M      Gold

# %% [markdown]
# ### Quanto cada status de cliente representa em vendas?

# %%
pd.merge(dataset_clientes, dataset_vendas, on="ClienteID").groupby(['Status'])['Total'].sum().plot.bar(logy=True,  color=['r', 'g', 'b'])
# Out:
# <Axes: xlabel='Status'>

# %% [markdown]
# ### Homens ou mulheres compram mais produtos?

# %%
pd.merge(dataset_clientes, dataset_vendas, on="ClienteID").groupby(['Sexo'])['Total'].sum().plot.pie()
# Out:
# <Axes: ylabel='Total'>

# %% [markdown]
# ### Quais são os maiores clientes?

# %%
pd.merge(dataset_clientes, dataset_vendas, on="ClienteID").groupby(['Cliente'])['Total'].sum().nlargest(5).plot.bar(s)
# Out:
# <Axes: xlabel='Cliente'>

# %% [markdown]
# ### Quais são os melhores vendedores?

# %%
pd.merge(dataset_vendedores, dataset_vendas, on="VendedorID").groupby(['Vendedor'])['Total'].sum().nlargest(5).plot.bar()
# Out:
# <Axes: xlabel='Vendedor'>

# %% [markdown]
# ### Quais são os piores vendedores?

# %%
pd.merge(dataset_vendedores, dataset_vendas, on="VendedorID").groupby(['Vendedor'])['Total'].sum().nsmallest(5).sort_values(ascending=False).plot.bar()
# Out:
# <Axes: xlabel='Vendedor'>
